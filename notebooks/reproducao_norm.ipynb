# %% [markdown]
# # setup

# %%
import os

if os.getcwd().split('/')[-1] == 'notebooks':
    os.chdir('..')

# %%
from dataloaders.feno import CODE, CODEsplit

# %% [markdown]
# # init

# %%
database = CODE()

# %% [markdown]
# # draft

# %%
trn_ds = CODEsplit(database, database.trn_idx_dict)
val_ds = CODEsplit(database, database.val_idx_dict)
tst_ds = CODEsplit(database, database.tst_idx_dict)

# %%
database.metadata
# Out:
#         exam_id       age  is_male  nn_predicted_age  1dAVb   RBBB   LBBB  \
# 0       1169160 -0.782426     True         40.160484  False  False  False
# 1       2873686  1.005538     True         67.059440  False  False  False
# 2        168405  0.699030     True         79.621740  False  False  False
# 3        271011 -0.629172     True         69.750260  False  False  False
# 4        384368  1.005538     True         78.873460  False  False  False
# ...         ...       ...      ...               ...    ...    ...    ...
# 307635   236469 -1.395442     True         29.119510  False  False  False
# 307636  1123951 -1.037849     True         35.893005  False  False  False
# 307637   954704  1.005538    False         68.169136  False  False  False
# 307638   589697  1.107708    False         78.080810  False  False  False
# 307639  1576698 -1.344358    False         31.939650  False  False  False
#
#            SB     ST     AF  patient_id  death     timey  normal_ecg  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(database.metadata['age'].values.reshape(-1, 1));

# %%
database.metadata['age'] = scaler.transform(database.metadata['age'].values.reshape(-1, 1))
